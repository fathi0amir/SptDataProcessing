# %% [markdown]
# ### Imports

# %%
# %% # MARK: Imports
from pathlib import Path # noqa: F401
from re import sub # noqa: F401
import numpy as np # noqa: F401
import pandas as pd # noqa: F401
import plotly.express as px # noqa: F401
import importlib
import holoviews as hv # noqa: F401
from holoviews import opts # noqa: F401
import holoviews.operation.datashader as hd # noqa: F401 & datashader, dynspread, rasterize, shade, spread``
from bokeh.themes import Theme

# Custom modules
import util.data_preprocessing as dpp
import util.analysis_functions as nlss
import util.look_and_feel as laf
import util.constants as const

hv.extension('bokeh') #type: ignore

# * ====================================
# * Reload modules
# Reload modules to ensure the latest changes are applied
def reload_modules():
    """Reloads the custom modules to ensure the latest changes are applied.
    """
    importlib.reload(const)
    importlib.reload(dpp)
    importlib.reload(nlss)
    importlib.reload(laf)

# Call the reload_modules() function to ensure all modules are up-to-date
reload_modules()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f14a402b-3e33-40f9-9b45-bb3fb3f29182'>
#   <div id="e4075b14-9620-433e-840d-9e5b2dfb9bf3" data-root-id="f14a402b-3e33-40f9-9b45-bb3fb3f29182" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4cee3bd6-cb8f-44d2-89cc-bd791f3e6d44":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"7cdef4ae-a4cd-46b1-941c-3fb0143a7140","attributes":{"notifications":{"type":"object","name":"Notifications","id":"c1de0256-16f1-4d6a-b410-aa12de730985"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f14a402b-3e33-40f9-9b45-bb3fb3f29182"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"74cb9c4b-0f2e-412b-9149-c9276660c8f2","attributes":{"plot_id":"f14a402b-3e33-40f9-9b45-bb3fb3f29182","comm_id":"f0d6c8dc35704e00be59b058b04785da","client_comm_id":"130bb2c7b2ff4a9fab313669653b813d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"4cee3bd6-cb8f-44d2-89cc-bd791f3e6d44","roots":{"f14a402b-3e33-40f9-9b45-bb3fb3f29182":"e4075b14-9620-433e-840d-9e5b2dfb9bf3"},"root_ids":["f14a402b-3e33-40f9-9b45-bb3fb3f29182"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ### Load data from <span style="color:red"><em>One Directory</em></span>
#
# Use <span style="color:red"><em>One Directory</em></span> or <span style="color:red"><em>Many Directories</em></span> to load data.

# %%
reload_modules()
data_wd = Path(r"data\2 50 TAT\BMP50TAT-20260610-S2-00267")
# df = dpp.load_trackmate_csv_files(data_wd)
df = dpp.load_trackpy_parquet(data_wd, suffix='-tracks', exposure_time=const.DT, pixel_in_nm=const.PIXEL_IN_NM)
print(f"Number of tracks before filtering: {len(df['UID'].unique())}")
df

# %% [markdown]
# ### Load Data from <span style="color:red"><em>Many Directories</em></span>
#
# Use <span style="color:red"><em>One Directory</em></span> or <span style="color:red"><em>Many Directories</em></span> to load data.

# %%
reload_modules()

# 1. Define a list of your data directories
# Replace these with your actual paths

data_wd = Path(r"data\2 50 TAT")
data_dirs = [
    data_wd / "BMP50TAT-20260610-S2-00265",
    data_wd / "BMP50TAT-20260610-S2-00266",
    data_wd / "BMP50TAT-20260610-S2-00267",
    data_wd / "BMP50TAT-20260610-S2-00268",
    data_wd / "BMP50TAT-20260610-S2-00269",
]

all_dfs = []
for dir in data_dirs:
    print(f"Loading data from: {dir}")
    # Call the existing function for each directory
    temp_df = dpp.load_trackpy_parquet(dir, suffix='-tracks', exposure_time=const.DT, pixel_in_nm=const.PIXEL_IN_NM)
    all_dfs.append(temp_df)

# Concatenate all dataframes into a single one
df = pd.concat(all_dfs, ignore_index=True)

print(f"Number of tracks before filtering: {len(df['UID'].unique())}")
df

# %% [markdown]
# ### Load Data from <span style="color:red"><em>Clean, Filtered Data</em></span>
#
# Use <span style="color:red"><em>One Directory</em></span> or <span style="color:red"><em>Many Directories</em></span>, or <span style="color:red"><em>Clean, Filtered Data</em></span> to load data.
# This will load the data from a parquet file saved from a previous run of the pipeline. If the data with `_msd` suffix is loaded don't run the MSD calculation, which is the most time-consuming step in the pipeline.

# %%
reload_modules()
data_wd = Path(r"data\2 50 TAT")
# df = pd.read_parquet(data_wd / "filtered_tracks.parquet")
df = pd.read_parquet(data_wd / "filtered_tracks_with_msd.parquet")
print(f"Number of tracks loaded: {len(df['UID'].unique())}")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='75b6ab5c-6334-4230-a584-f018b016bdc7'>
#   <div id="c3ba1c55-a474-410d-b9b8-d6b6190b3e55" data-root-id="75b6ab5c-6334-4230-a584-f018b016bdc7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f9e5bdd8-8659-467e-a513-0a0cced71d91":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"e23e287f-53ae-4591-b0c7-e4e6177c6f51","attributes":{"notifications":{"type":"object","name":"Notifications","id":"56db8032-0c21-45c2-9859-71f0cf533dd1"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"75b6ab5c-6334-4230-a584-f018b016bdc7"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ba5a423d-bc6b-409d-8a83-95a4926a97e2","attributes":{"plot_id":"75b6ab5c-6334-4230-a584-f018b016bdc7","comm_id":"af9e1cc96b8e41928e90fa13d6f7e9a0","client_comm_id":"eaad62f94edc4dff81cdc0b22d30e75c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"f9e5bdd8-8659-467e-a513-0a0cced71d91","roots":{"75b6ab5c-6334-4230-a584-f018b016bdc7":"c3ba1c55-a474-410d-b9b8-d6b6190b3e55"},"root_ids":["75b6ab5c-6334-4230-a584-f018b016bdc7"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# Number of tracks loaded: 7892

# %% [markdown]
# ### Remove Stationary and short Tracks
#
# Also saves all the filtered tracks to a parquet file in the working directory.

# %%
reload_modules()
df = nlss.drop_short_trajectories(df)
print(f"Number of tracks after filtering short trajectories: {len(df['UID'].unique())}")
df = nlss.drop_stationary_trajectories(df)
print(f"Number of tracks after filtering stationary trajectories: {len(df['UID'].unique())}")

df.to_parquet(data_wd / "filtered_tracks.parquet", index=False)

# %% [markdown]
# ### Calculate MSD

# %%
reload_modules()
df = df.groupby('UID').apply(nlss.calculate_msd).reset_index(level='UID')
df.to_parquet(data_wd / "filtered_tracks_with_msd.parquet", index=False)

# %% [markdown]
# ### Normalized MSD (To first point)

# %%
reload_modules()
df['MSD_norm'] = df.groupby('UID')['MSD'].transform(lambda x: x / x.iloc[0])
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b22dcf9f-5c39-41d6-8ae3-a58450a686b1'>
#   <div id="e524a477-ff35-40cf-afc9-53e1a26aec77" data-root-id="b22dcf9f-5c39-41d6-8ae3-a58450a686b1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8cc98972-c34e-456a-ada6-18a241b98b5a":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"fe90d4a1-a649-4cd7-8cb3-48cbfc5954b6","attributes":{"notifications":{"type":"object","name":"Notifications","id":"fb10437d-e039-4951-be62-51a723c09c7d"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b22dcf9f-5c39-41d6-8ae3-a58450a686b1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"927dba01-8fe0-484c-86f5-54db28cbf6f2","attributes":{"plot_id":"b22dcf9f-5c39-41d6-8ae3-a58450a686b1","comm_id":"da83deabd87d4f1ba23a9a5ad6894e8f","client_comm_id":"ac944d2558194681ab8151f67954bf53"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"8cc98972-c34e-456a-ada6-18a241b98b5a","roots":{"b22dcf9f-5c39-41d6-8ae3-a58450a686b1":"e524a477-ff35-40cf-afc9-53e1a26aec77"},"root_ids":["b22dcf9f-5c39-41d6-8ae3-a58450a686b1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %% [markdown]
# ### Calculate Normal Diffusion Coefficient

# %%
reload_modules()
df = df.groupby('UID').apply(nlss.calculate_diff_d)
df = df.reset_index(level='UID') if 'UID' not in df.columns else df.reset_index(drop=True)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c5ce133e-db01-415c-a502-4a4c3f3f7615'>
#   <div id="f166115b-c7a6-4aed-9ff0-043c62379a99" data-root-id="c5ce133e-db01-415c-a502-4a4c3f3f7615" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fbed9c9f-1e53-4ad0-9395-8f3245767b2e":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"e763bae0-e984-47e9-86d4-d61440de4c3f","attributes":{"notifications":{"type":"object","name":"Notifications","id":"d1e3da57-1437-42c0-a5dc-22f17b261a2e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c5ce133e-db01-415c-a502-4a4c3f3f7615"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ec5a962b-bd33-4302-9cb1-b0a40faf3967","attributes":{"plot_id":"c5ce133e-db01-415c-a502-4a4c3f3f7615","comm_id":"ea537bfc11874edf94f16cff55385031","client_comm_id":"0582590f4b224ed78f97d4468985fedf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"fbed9c9f-1e53-4ad0-9395-8f3245767b2e","roots":{"c5ce133e-db01-415c-a502-4a4c3f3f7615":"f166115b-c7a6-4aed-9ff0-043c62379a99"},"root_ids":["c5ce133e-db01-415c-a502-4a4c3f3f7615"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %% [markdown]
# ### Flagging alpha values based on linear fit (MSD vs time lag) and find the corresponding D values
# Alpha values are grouped into 3 categories:
# - In: alpha $\leq$ 0.8
# - Cross: 0.8 $\leq$ alpha $\leq$ 1.2
# - Out: alpha $\geq$ 1.2
#
# Values are ignored if $\leq$ 0.2. Criteria are set in `util/constants.py` file.

# %%
df = df.groupby('UID').apply(nlss.flag_alpha_by_fit)
df = df.reset_index(level='UID') if 'UID' not in df.columns else df.reset_index(drop=True)

df = df.groupby('UID').apply(nlss.calc_d_fix_alpha)
df = df.reset_index(level='UID') if 'UID' not in df.columns else df.reset_index(drop=True)

# %% [markdown]
# ### Group by in/out/cross
# *traj_label* column should be present in the dataframe.

# %%
df_in = df[df['traj_label'] == 'in']
df_out = df[df['traj_label'] == 'out']
df_cross = df[df['traj_label'] == 'cross']

# %% [markdown]
# ### MSD vs Time Lag (Log-Log) Plot

# %%
reload_modules()
# laf.holoviz_plot_msd_loglog_fast(df, bin_num=150)

# fig = laf.plotly_plot_norm_loglog_msd(df)
# fig.show(renderer="svg")

# laf.vega_plot_msd_loglog_fast(df, bin_size=0.03)

def plot_msd_vs_time_lag(df):
    hist, edges_x, edges_y = nlss.log_binned_histogram2d(df, x_column='Lag_T', y_column='MSD_norm', bins_per_decade=20)
# hist, edges_x, edges_y = nlss.lin_binned_histogram2d(df, x_column='Lag_T', y_column='MSD_norm', x_bin_width=0.02, y_bin_width=20)
    hist = hist.astype(float)  # Convert to float to allow NaN values
    hist[hist < 5] = np.nan  # Replace zeros with NaN for better visualization
    hv.renderer("bokeh").theme = Theme(filename="util/bokeh-theme-light.yaml")
    msd_quad = hv.QuadMesh((edges_x, edges_y, hist.T)).opts(
    logx=True, 
    logy=True, 
    xlabel='Lag Time (s)', 
    ylabel='MSD / MSD(Δt=0)', 
    title='Heatmap of MSD vs Lag Time', 
    xlim=(1e-2, 1e1),
    ylim=(1e0, 1e3),
    # colorbar=True,
    cmap='viridis',
    clim=(0, 1200))
    msd_quad.opts(laf.HV_BOKEH_BASIC)
    msd_quad.opts(hooks=[laf.bokeh_add_topright_log_axes])
    return msd_quad

plot_msd_vs_time_lag(df)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6ef2e510-2452-4fe9-82bf-cdbc388ad57b'>
#   <div id="f116caa6-6dbd-4be1-995f-3e06ab5b88a6" data-root-id="6ef2e510-2452-4fe9-82bf-cdbc388ad57b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5d9e37be-810b-4793-a783-a2060e0cbcbd":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"8c85c896-35fc-4736-a837-730e23dea7f2","attributes":{"notifications":{"type":"object","name":"Notifications","id":"9a50171d-9afe-4c0a-89c1-cb1098768b87"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"6ef2e510-2452-4fe9-82bf-cdbc388ad57b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"71cdc806-b3e9-418c-bd01-193ba79742dd","attributes":{"plot_id":"6ef2e510-2452-4fe9-82bf-cdbc388ad57b","comm_id":"93c08b144f984a0383d149d7a7888ce5","client_comm_id":"2675efbd9a7941b0bbba6c8add31f346"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"5d9e37be-810b-4793-a783-a2060e0cbcbd","roots":{"6ef2e510-2452-4fe9-82bf-cdbc388ad57b":"f116caa6-6dbd-4be1-995f-3e06ab5b88a6"},"root_ids":["6ef2e510-2452-4fe9-82bf-cdbc388ad57b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# :QuadMesh   [x,y]   (z)

# %% [markdown]
# ### Plot Diffusion Coefficient Histogram

# %%
reload_modules()

def plot_diff_coeff():
    hist, edges = nlss.log_binned_histogram(df_out, column='D_Fixed_Alpha', min_log_d=-3, max_log_d=0, bins_per_decade=10)

    hv.renderer("bokeh").theme = Theme(filename="util/bokeh-theme-light.yaml")
    d_hist = hv.Histogram((hist, edges)).opts(logx=True, logy=False, xlabel='D (µm²/s)', ylabel='Count', title='Histogram of D')
    d_hist.opts(laf.HV_BOKEH_BASIC)
    d_hist.opts(hooks=[laf.bokeh_add_topright_logxliny_axes])
    return d_hist

plot_diff_coeff()

# %% [markdown]
# ### Plot histogram of alpha values

# %%
reload_modules()

def plot_alpha_hist():
    hist, edges = nlss.linear_binned_histogram(df_out, column='Alpha', bin_width=0.05)

    hv.renderer("bokeh").theme = Theme(filename="util/bokeh-theme-light.yaml")
    alpha_hist = hv.Histogram((hist, edges)).opts(
    xlabel='𝛼', 
    ylabel='Count', 
    title='Histogram of 𝛼',
    xlim=(0, 1.6))
    alpha_hist.opts(laf.HV_BOKEH_BASIC)
    alpha_hist.opts(hooks=[laf.bokeh_add_topright_linear_axes])
    return alpha_hist

plot_alpha_hist()

# %% [markdown]
# ### Plot Stats for in/out/cross groups

# %%
reload_modules()
def diff_type_vs_traj_group_stacked_bar_plot():
    plot_df = nlss.domain_diff_type_stacked_df(df)

# 6. Create the stacked bars
    bars = hv.Bars(
    plot_df,
    kdims=['traj_label', 'Alpha_Flag_Fit'],
    vdims=['Proportion']
).opts(
    stacked=True,
    xlabel='Trajectory Label',
    ylabel='Proportion',
    title='Diffusion Types by Trajectory Group',
    ylim=(0, 1.21),
    color='Alpha_Flag_Fit',
    show_legend=True,
    cmap={
        'normal': '#2ca02c',  # green
        'sub':    '#1f77b4',  # blue
        'sup':    '#ff7f0e',  # orange
    },
)

# 7. Create labels and overlay them on the bars
    labels = hv.Labels(
    plot_df,
    kdims=['traj_label', 'label_y_pos'],
    vdims=['label']
).opts(
    text_color='white',
    text_align='center',
    text_baseline='middle'
)

# 8. Combine bars + labels and apply your theme
    combined = bars * labels
    combined.opts(laf.HV_BOKEH_BASIC)
    combined.opts(hooks=[laf.bokeh_add_topright_linear_axes, laf.set_legend_top_horizontal])
    return combined

diff_type_vs_traj_group_stacked_bar_plot()

# %% [markdown]
# ### 𝛼 for all groups

# %%
reload_modules()

def regional_combined_alpha_histogram(df):

    df_in = df[df['traj_label'] == 'in']
    hist_in, edges_in = nlss.linear_binned_histogram(df_in, column='Alpha', bin_width=0.05)
    hist_in = hist_in/max(hist_in)  # Normalize the histogram
    alpha_hist_in = hv.Histogram((hist_in, edges_in), label='in').opts(alpha=0.5)

    df_out = df[df['traj_label'] == 'out']
    hist_out, edges_out = nlss.linear_binned_histogram(df_out, column='Alpha', bin_width=0.05)
    hist_out = hist_out/max(hist_out)  # Normalize the histogram
    alpha_hist_out = hv.Histogram((hist_out, edges_out), label='out').opts(alpha=0.5)

    combined_alpha_hist = alpha_hist_in * alpha_hist_out

    return combined_alpha_hist

def plot_alpha_for_traj_group(df):
    combined_alpha_hist = regional_combined_alpha_histogram(df)

    hv.renderer("bokeh").theme = Theme(filename="util/bokeh-theme-light.yaml")

# Apply overall options and hooks to the combined plot
    combined_alpha_hist.opts(
    xlabel='𝛼',
    ylabel='Count',
    xlim=(0, 1.6),
    ylim=(0, 1.2),
    title='Histograms of 𝛼 for Different Trajectory Groups',
    legend_position='top_right', # Adjust as needed
    show_legend=True,
).opts(laf.HV_BOKEH_BASIC).opts(
    hooks=[laf.bokeh_add_topright_linear_axes, laf.set_legend_top_horizontal]
)

    return combined_alpha_hist

plot_alpha_for_traj_group(df)

# %% [markdown]
# ### Find confinement ratio for each group

# %%
def calculate_confinement_ratio_traj_group():
    # One row per trajectory
    traj_level = df.groupby('UID', as_index=False).first()

# Confinement ratio = fraction of sub-diffusive trajectories in each traj_label group
    confinement_ratio = (
    traj_level.assign(is_confined=traj_level['Alpha_Flag_Fit'].eq('sub'))
    .groupby('traj_label')['is_confined']
    .agg(['sum', 'count'])
    .assign(confinement_ratio=lambda x: x['sum'] / x['count'])
    .reset_index()
    .rename(columns={'sum': 'n_confined', 'count': 'n_total'})
)

    return confinement_ratio

calculate_confinement_ratio_traj_group()

# %% [markdown]
# ### Find confinement domains (size and number) for each group

# %%
# 1. Calculate the length of each trajectory (number of steps)
# We can count the number of rows for each unique UID
def get_long_trajectories(df, traj_length_threshold=300, traj_label='cross'):
    trajectory_lengths = df.groupby('UID')['Frame'].count().reset_index()
    trajectory_lengths.rename(columns={'Frame': 'Trajectory_Length'}, inplace=True)

# 2. Identify UIDs that have a length greater than the threshold
    long_trajectories_uids = trajectory_lengths[trajectory_lengths['Trajectory_Length'] > traj_length_threshold]['UID'].unique()

# 3. Filter the original df for 'traj_label == 'in'' and for the identified UIDs
    df_in_long_trajectories = df[
        (df['traj_label'] == traj_label) & 
        (df['UID'].isin(long_trajectories_uids))
    ]   
    
    return df_in_long_trajectories

df_in_long_trajectories = get_long_trajectories(df, traj_length_threshold=300, traj_label='in')

print(f"Number of trajectories in df_in_long_trajectories: {len(df_in_long_trajectories['UID'].unique())}")
df_in_long_trajectories
# Out:
# Number of trajectories in df_in_long_trajectories: 6
#                                    UID             Y             X  \
# 201770  BMP50TAT-20260610-S2-00270-038  10572.189958   4602.775537
# 201771  BMP50TAT-20260610-S2-00270-038  10515.313316   4682.337568
# 201772  BMP50TAT-20260610-S2-00270-038  10619.238769   4720.652043
# 201773  BMP50TAT-20260610-S2-00270-038  10727.857295   4761.326505
# 201774  BMP50TAT-20260610-S2-00270-038  10843.677856   4762.209494
# ...                                ...           ...           ...
# 701312  BMP50TAT-20260610-S2-00293-134  16232.556525  32780.108845
# 701313  BMP50TAT-20260610-S2-00293-134  16238.813280  32773.675882
# 701314  BMP50TAT-20260610-S2-00293-134  16251.665210  32825.393562
# 701315  BMP50TAT-20260610-S2-00293-134  16235.018459  32807.055881
# 701316  BMP50TAT-20260610-S2-00293-134  16207.558474  32825.370033
#
#               mass      size       ecc     signal  raw_mass        ep  Frame  \
# 201770  134.521047  1.777859  0.064950  11.268172    3403.0  0.128019      0
# 201771  154.158647  1.856297  0.108272  11.101580    3433.0  0.117865      1
# 201772  119.766389  1.713427  0.176657  10.589525    3294.0  0.172581      2
# 201773  148.929677  1.620808  0.014156  15.257544    3374.0  0.126513      3
# 201774  158.900208  1.635156  0.087746  15.182346    3419.0  0.113217      4
# ...            ...       ...       ...        ...       ...       ...    ...
# 701312  134.742963  1.666692  0.186336  11.975774    3353.0  0.174226    345
# 701313  128.287915  1.746820  0.236504  11.101508    3329.0  0.182417    346
# 701314  162.309888  1.618855  0.174779  16.197019    3393.0  0.172783    347
# 701315  164.177927  1.656266  0.202956  15.541382    3401.0  0.153910    348
# 701316  132.874986  1.756942  0.125083  10.108248    3385.0  0.159872    349
#
#         ...     T       MSD Lag_T  MSD_norm    D_Norm  D_Norm_error  \
# 201770  ...  0.00  0.006381  0.02  1.000000  0.074018      0.000440
# 201771  ...  0.02  0.012204  0.04  1.912649  0.074018      0.000440
# 201772  ...  0.04  0.018372  0.06  2.879321  0.074018      0.000440
# 201773  ...  0.06  0.024566  0.08  3.849990  0.074018      0.000440
# 201774  ...  0.08  0.030064  0.10  4.711653  0.074018      0.000440
# ...     ...   ...       ...   ...       ...       ...           ...
# 701312  ...  6.90       NaN   NaN       NaN  0.002408      0.000044
# 701313  ...  6.92       NaN   NaN       NaN  0.002408      0.000044
# 701314  ...  6.94       NaN   NaN       NaN  0.002408      0.000044
# 701315  ...  6.96       NaN   NaN       NaN  0.002408      0.000044
# 701316  ...  6.98       NaN   NaN       NaN  0.002408      0.000044
#
#         Alpha_Flag_Fit     Alpha  D_Fixed_Alpha  D_Fixed_Alpha_error
# 201770          normal  0.971796       0.075819             0.000504
# 201771          normal  0.971796       0.075819             0.000504
# 201772          normal  0.971796       0.075819             0.000504
# 201773          normal  0.971796       0.075819             0.000504
# 201774          normal  0.971796       0.075819             0.000504
# ...                ...       ...            ...                  ...
# 701312             sub  0.504897       0.003744             0.000020
# 701313             sub  0.504897       0.003744             0.000020
# 701314             sub  0.504897       0.003744             0.000020
# 701315             sub  0.504897       0.003744             0.000020
# 701316             sub  0.504897       0.003744             0.000020
#
# [2263 rows x 24 columns]

# %%
track = df_in_long_trajectories[df_in_long_trajectories['UID'] == df_in_long_trajectories['UID'].unique()[1]]
track = nlss.calc_confinement_level(track)
track = track[int(const.WINDOW_SIZE/2):-const.WINDOW_SIZE]  # Remove the last few rows where the moving window cannot be computed
# track.info()
# Columns of interest: MW_D, Conf_Level, T
fig = px.line(track, x='T', y='Conf_Level', 
                title=f'Confinement Level vs T {const.WINDOW_SIZE} & {const.MSD_FIT_POINTS}')
fig.update_layout(
    template='plotly_white', 
    xaxis=dict(
        title='T (s)',
        showline=True,      # Show axis line
        showgrid=True,      # Show grid lines
        showticklabels=True,
        linecolor='black',
        ticks='inside',
        mirror=True,        # Mirror the ticks on the opposite side
        linewidth=2,        # Width of the axis line
    ),
    yaxis=dict(
        title='Confinement Level',
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='black',
        ticks='inside',
        mirror=True,
        linewidth=2,
    )
)
laf.set_plotly_config(fig) # wrapper for fig.show(config=config)

# %% [markdown]
# ### Transient MSD analysis for each group

# %%
reload_modules()  # Reload modules to ensure the latest changes are applied

track = df_in_long_trajectories[df_in_long_trajectories['UID'] == df_in_long_trajectories['UID'].unique()[0]]

track = nlss.calculate_diff_d_moving_window(track)
# track.info()
# Columns of interest: MW_D, Conf_Level, Frame
fig = px.line(
    track,
    x="Frame",
    y="MW_D",
    title=f"Transient MSD vs Frame {const.TMSD_WINDOW_SIZE} & {const.TMSD_FIT_POINTS}",
)
fig.update_layout(
    xaxis_title="Frame",
    yaxis_title="Transient MSD",
    # paper_bgcolor="rgb(255, 255, 255)",
    # plot_bgcolor="rgb(220, 220, 220)",
    template="presentation"
)
laf.set_plotly_config(fig) # wrapper for fig.show(config=config)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65'>
#   <div id="e91432c3-a52b-41f3-b7e7-bafacbf1a2fb" data-root-id="48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f411e32d-9b14-483a-9e2f-2e84fea5f524":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"6f6d6782-a57c-4ddc-b651-46d2bef20e41","attributes":{"notifications":{"type":"object","name":"Notifications","id":"df766e70-328d-4a6c-95f9-40d4fe6c152f"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c0f62e1d-4b4e-428c-b575-668229d90b99","attributes":{"plot_id":"48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65","comm_id":"f86b91d3b30a4869a44b9ea05888aca4","client_comm_id":"a8967c489f334fdea43a77237e8ad1d5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"f411e32d-9b14-483a-9e2f-2e84fea5f524","roots":{"48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65":"e91432c3-a52b-41f3-b7e7-bafacbf1a2fb"},"root_ids":["48e8fdf9-c0f9-436c-9ed4-9a72b3adcd65"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.23.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.9.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %%
reload_modules()

laf.plotly_plot_alpha_hist(df_in)
laf.plotly_plot_alpha_hist(df_out)
laf.plotly_plot_alpha_hist(df_cross)

# %% [markdown]
# ### Save the holoviews (bokeh) plots as HTML files

# %%
import panel as pn

pane = pn.pane.HoloViews(d_hist)
pane.save('output.svg')  # also requires selenium

# %% [markdown]
# ### Other for testing

# %%
reload_modules()
laf.plotly_plot_diff_coef_hist(df, column='D_Fixed_Alpha', nbins=500)
# laf.plotly_plot_diff_coef_hist(df_in, column='D_Fixed_Alpha', nbins=150)
# laf.plotly_plot_diff_coef_hist(df_out, column='D_Fixed_Alpha', nbins=150)
# laf.plotly_plot_diff_coef_hist(df_cross, column='D_Fixed_Alpha', nbins=150)
# laf.plotly_plot_diff_coef_logloghist(df, column='D_Norm')
# laf.plotly_plot_diff_coef_loglogarea(df, column='D_Norm')
